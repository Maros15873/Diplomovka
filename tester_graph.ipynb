# %%
# %run interpreter.ipynb
# Out:
# ..........................................................................
# ----------------------------------------------------------------------
# Ran 74 tests in 0.682s
#
# OK
# ................................................................................
# ----------------------------------------------------------------------
# Ran 80 tests in 0.722s
#
# OK
# ..........................................................................................
# ----------------------------------------------------------------------
# Ran 90 tests in 0.935s
#
# OK
# ................................................................................................................
# ----------------------------------------------------------------------
# Ran 112 tests in 2.554s
#
# OK
# ..................................................................................................................
# ----------------------------------------------------------------------
# ...

# %%
domain = {'a','b','c','d'}
codomain = {'a','b','c','d','e'}
relation1 = Function({('c','c'),('a','b'),('b','d'),('d','a'),('e','a')}, codomain,domain, True)
print(relation1.is_function())
print(relation1.is_injective())
print(relation1.is_surjective())
print(relation1.is_bijective())
# Out:
# True
# False
# True
# False

# %%
expression = "(R == S) -> (R == S)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)
relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('b','b'),('c','c'),('a','b'),('b','c'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','b'),('b','c'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> (R == S)'

# %%
expression = "(R != S) -> (R != S)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('b','b'),('c','c'),('a','b'),('b','c'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','b'),('b','c'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)

relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> (R != S)'

# %%
expression = "(R > S) -> (R > S)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R > S)'

# %%
expression = "(R >= S) -> (R >= S)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)

relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R >= S)'

# %%
expression = "(S < R) -> (S < R)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (S < R)'

# %%
expression = "(S <= R) -> (S <= R)"

domain = {'a','b','c','d'}

#--- error ---- TRUE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b')}, domain, True)

#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)
#relation2 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain,domain, True)
#relation2 = BinaryRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)

#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)

relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d')}, domain, True)
relation2 = PartialOrder({('c','c'),('a','a'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)


variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (S <= R)'

# %%
expression = "R is reflexive -> R is reflexive"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d'),('d','d'),('b','b')}, domain, True)
#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)

#--- error ---- FALSE
#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d')}, domain, True)
#PartialOrder is always reflexive

variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is reflexive'

# %%
expression = "R is symmetric -> R is symmetric"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('a','b'),('b','d'),('d','d'),('b','a'),('d','b')}, domain, True)

#--- error ---- FALSE
#relation1 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','d'),('d','d'),('b','b')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is symmetric'

# %%
expression = "R is asymmetric -> R is asymmetric"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('a','b'),('b','d'),('c','b')}, domain, True)
#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)

#--- error ---- FALSE
#relation1 = HomogeneousRelation({('a','b'),('b','d'),('d','d'),('b','a'),('d','b')}, domain, True)



variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is asymmetric'

# %%
expression = "R is antisymmetric -> R is antisymmetric"

domain = {'a','b','c','d'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('a','b'),('b','d'),('c','b'),('b','b')}, domain, True)
relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)

#--- error ---- FALSE
#relation1 = HomogeneousRelation({('a','b'),('b','d'),('d','d'),('b','a'),('d','b')}, domain, True)



variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is antisymmetric'

# %%
expression = "R is transitive -> R is transitive"

domain = {'a','b','c','d'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('a','b'),('b','d'),('a','d')}, domain, True)
#relation1 = PartialOrder({('c','c'),('a','a'),('a','b'),('b','b'),('d','d'),('a','c'),('a','d'),('c','d'),('b','d')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','b'),('b','d'),('d','d'),('b','a'),('d','b')}, domain, True)



variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is transitive'

# %%
expression = "R is total_order -> R is total_order"

domain = {'a','b','c'}

#--- error ---- TRUE
relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('b','c'),('b','a')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is total_order'

# %%
expression = "R is lattice -> R is lattice"

domain = {'a','b','c'}

#--- error ---- TRUE
relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
#relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('c','b'),('c','a')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is lattice'

# %%
expression = "R is injective -> R is injective"

domain = {'a','b','c','d'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('c','a'),('a','b'),('b','c'),('d','d')}, domain,codomain, True)
#False
relation1 = Function({('c','c'),('a','c'),('b','a'),('d','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is injective'

# %%
expression = "R is surjective -> R is surjective"

domain = {'a','b','c','d','e'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('c','a'),('a','b'),('b','c'),('d','d'),('e','e')}, domain,codomain, True)
#False
relation1 = Function({('c','c'),('a','b'),('b','a'),('d','a'),('e','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is surjective'

# %%
expression = "R is bijective -> R is bijective"

domain = {'a','b','c','d','e'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('a','a'),('b','b'),('c','c'),('d','d'),('e','e')}, domain,codomain, True)
#False
relation1 = Function({('c','c'),('a','b'),('b','d'),('d','a'),('e','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 2)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is bijective'
