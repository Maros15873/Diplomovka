# %%
# %run interpreter.ipynb
# Out:
# ..........................................................................
# ----------------------------------------------------------------------
# Ran 74 tests in 0.358s
#
# OK
# ...........
# ----------------------------------------------------------------------
# Ran 11 tests in 0.092s
#
# OK
# .................
# ----------------------------------------------------------------------
# Ran 17 tests in 0.133s
#
# OK
# ...........................
# ----------------------------------------------------------------------
# Ran 27 tests in 0.273s
#
# OK
# ...................................................
# ----------------------------------------------------------------------
# Ran 51 tests in 1.636s
#
# OK
# .....................................................
# ----------------------------------------------------------------------
# Ran 53 tests in 1.556s
#
# OK

# %%
expression1 = "(R is transitive and S is transitive) -> R|S is transitive"

domain = {1,2,3}

# --- good counterexample ---
#relation1 = HomogeneousRelation({(2,3)}, domain, True)
#relation2 = HomogeneousRelation({(1,2)}, domain, True)

# --- error condition ----
#relation1 = HomogeneousRelation({(1,2),(2,3)}, domain, True)
#relation2 = HomogeneousRelation({(1,2),(2,1),(2,2)}, domain, True)

# --- error conclusion ----
#relation1 = HomogeneousRelation({(1,1)}, domain, True)
#relation2 = HomogeneousRelation({(2,2)}, domain, True)

# --- error condition + conclusion ----
relation1 = HomogeneousRelation({(1,2),(2,3)}, domain, True)
relation2 = HomogeneousRelation({(1,2),(2,1),(1,1),(1,3),(2,2)}, domain, True)

# --- multiple error condition ----
#relation1 = HomogeneousRelation({(1,2),(2,3),(2,1)}, domain, True)
#relation2 = HomogeneousRelation({(1,2),(2,1)}, domain, True)

variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression1, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R is transitive and S is transitive)'
# '<<<ERROR - CONDITION>>> R is transitive'
# '<<<ERROR - CONDITION>>> S is transitive'
# '<<<ERROR - CONCLUSION>>> (R | S) is transitive'

# %%
expression2 = "(R is reflexive and S is symmetric) -> (R|S is transitive or R-S is antisymmetric)"

domain = {1,2,3}

# --- good counterexample ---
#relation1 = HomogeneousRelation({(1,1),(2,2),(3,3),(1,2),(2,3),(2,1)}, domain, True)
#relation2 = HomogeneousRelation({(1,1)}, domain, True)

# --- error condition ----
#relation1 = HomogeneousRelation({(1,1),(2,2),(1,2),(2,3),(2,1)}, domain, True)
#relation2 = HomogeneousRelation({(3,1)}, domain, True)

# --- error conclusion ----
#relation1 = HomogeneousRelation({(1,1),(2,2),(3,3)}, domain, True)
#relation2 = HomogeneousRelation({(1,1)}, domain, True)

# --- error condition + conclusion ----
relation1 = HomogeneousRelation({(1,1),(2,2),(1,2),(2,3),(2,1)}, domain, True)
relation2 = HomogeneousRelation({(3,3),(3,1),(3,2),(1,3),(1,2),(2,1)}, domain, True)

# --- multiple error condition ----
#relation1 = HomogeneousRelation({(2,3),(3,2)}, domain, True)
#relation2 = HomogeneousRelation({(1,2),(1,3)}, domain, True)

variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression2, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R is reflexive and S is symmetric)'
# '<<<ERROR - CONDITION>>> R is reflexive'
# '<<<ERROR - CONDITION>>> S is symmetric'
# '<<<ERROR - CONCLUSION>>> ((R | S) is transitive or (R - S) is antisymmetric)'
# '<<<ERROR - CONCLUSION>>> (R | S) is transitive'
# '<<<ERROR - CONCLUSION>>> (R - S) is antisymmetric'

# %%
expression = "R is reflexive -> R is reflexive"

domain = {'a','b','c'}
domain1 = {1,2,3}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('a','a'),('b','b'),('c','c')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','c'),('b','a'),('c','b'),('b','b')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is reflexive'

# %%
expression = "R is symmetric -> R is symmetric"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('b','b'),('a','b'),('b','a')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','c'),('b','a'),('c','b'),('b','b')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is symmetric'

# %%
expression = "R is asymmetric -> R is asymmetric"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('c','b'),('a','b'),('c','a')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','c'),('c','a'),('c','b'),('b','c'),('a','b'),('b','b')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is asymmetric'

# %%
expression = "R is antisymmetric -> R is antisymmetric"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('c','b'),('a','b'),('c','a'),('a','a'),('c','c')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','c'),('c','a'),('c','b'),('b','c'),('a','b'),('b','b')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is antisymmetric'

# %%
expression = "R is not transitive -> R is not transitive"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('a','b'),('b','c'),('a','c'),('a','a')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('a','b'),('b','c'),('b','a')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is not transitive'

# %%
expression = "R is total_order -> R is total_order"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('b','c'),('b','a')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is total_order'

# %%
expression = "R is lattice -> R is lattice"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('b','c'),('a','c')}, domain, True)


variables = {'R':relation1}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is lattice'

# %%
expression = "(R == S) -> (R == S)"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
#relation2 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)



variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R == S)'

# %%
expression = "(R != S) -> (R != S)"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
#relation2 = PartialOrder({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
relation2 = HomogeneousRelation({('c','c'),('a','a'),('a','b'),('b','c')}, domain, True)



variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> (R != S)'

# %%
expression = "(R > S) -> (R > S)"

domain = {'a','b','c'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)
#relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)



variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> (R > S)'

# %%
expression = "(R >= S) -> (R >= S)"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)
#relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)

#--- error ---- FALSE
relation1 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)
relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)



variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R >= S)'

# %%
expression = "(R < S) -> (R < S)"

domain = {'a','b','c'}

#--- error ---- TRUE
#relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)
#relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
relation1 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)
relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)

variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> (R < S)'

# %%
expression = "(R <= S) -> (R <= S)"

domain = {'a','b','c'}

#--- error ---- TRUE
relation1 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain, True)
relation2 = HomogeneousRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c'),('a','c')}, domain, True)

#--- error ---- FALSE
#relation1 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b'),('b','c')}, domain,domain, True)
#relation2 = BinaryRelation({('b','b'),('c','c'),('a','a'),('a','b')}, domain,domain, True)

variables = {'R':relation1, 'S':relation2}

interpreter = Interpreter(variables, domain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> (R <= S)'

# %%
expression = "R is injective -> R is injective"

domain = {'a','b','c','d'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('c','a'),('a','b'),('b','c'),('d','d')}, domain,codomain, True)
#False
relation1 = Function({('c','c'),('a','c'),('b','a'),('d','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is injective'

# %%
expression = "R is surjective -> R is surjective"

domain = {'a','b','c','d','e'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('c','a'),('a','b'),('b','c'),('d','d'),('e','e')}, domain,codomain, True)
#False
relation1 = Function({('c','c'),('a','b'),('b','a'),('d','a'),('e','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONDITION>>> R is surjective'

# %%
expression = "R is bijective -> R is bijective"

domain = {'a','b','c','d','e'}
codomain = {'a','b','c','d','e'}

#True
relation1 = Function({('a','a'),('b','b'),('c','c'),('d','d'),('e','e')}, domain,codomain, True)
#False
#relation1 = Function({('c','c'),('a','b'),('b','d'),('d','a'),('e','a')}, domain,codomain, True)

variables = {'R':relation1}

interpreter = Interpreter(variables, domain|codomain, True)

#--------------------------------------------------------------------------------------------------------------

generator = interpreter.analyze_all(expression, 1)

for p in generator: display(p);
# Out:
# '<<<ERROR - CONCLUSION>>> R is bijective'
